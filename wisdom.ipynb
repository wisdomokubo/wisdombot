# %%
! git clone https://github.com/wisdomokubo/wisdombot
# Out:
# Cloning into 'wisdombot'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 88 (delta 15), reused 0 (delta 0), pack-reused 59
# Receiving objects: 100% (88/88), 99.07 KiB | 1.18 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
! pip install -r wisdombot/requirements.txt
# Out:
# Collecting streamlit==1.25.0 (from -r wisdombot/requirements.txt (line 1))
#   Downloading streamlit-1.25.0-py2.py3-none-any.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 22.6 MB/s eta 0:00:00
# Collecting streamlit-option-menu==0.3.6 (from -r wisdombot/requirements.txt (line 2))
#   Downloading streamlit_option_menu-0.3.6-py3-none-any.whl (799 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.2/799.2 kB 45.4 MB/s eta 0:00:00
# Collecting streamlit_chat==0.1.1 (from -r wisdombot/requirements.txt (line 3))
#   Downloading streamlit_chat-0.1.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.9 MB/s eta 0:00:00
# Collecting langchain==0.0.310 (from -r wisdombot/requirements.txt (line 4))
#   Downloading langchain-0.0.310-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 59.5 MB/s eta 0:00:00
# Collecting sentence_transformers==2.2.2 (from -r wisdombot/requirements.txt (line 5))
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pinecone-client==2.2.4 (from -r wisdombot/requirements.txt (line 6))
#   Downloading pinecone_client-2.2.4-py3-none-any.whl (179 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.4/179.4 kB 25.7 MB/s eta 0:00:00
# Collecting unstructured==0.10.19 (from -r wisdombot/requirements.txt (line 7))
#   Downloading unstructured-0.10.19-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.3 MB/s eta 0:00:00
# Collecting openai==0.28.1 (from -r wisdombot/requirements.txt (line 8))
#   Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (8.1.7)
# Collecting importlib-metadata<7,>=1.4 (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: packaging<24,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: pillow<10,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (14.0.2)
# Collecting pympler<2,>=0.9 (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: requests<3,>=2.18 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (4.9.0)
# Collecting tzlocal<5,>=1.1 (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Collecting validators<1,>=0.2 (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 27.6 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8 (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 75.5 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (6.3.2)
# Collecting watchdog>=2.1.5 (from streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (3.9.3)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4))
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.1.0,>=0.0.40 (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4))
#   Downloading langsmith-0.0.92-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (4.37.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (4.66.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (0.16.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (0.20.3)
# Collecting loguru>=0.5.0 (from pinecone-client==2.2.4->-r wisdombot/requirements.txt (line 6))
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 9.5 MB/s eta 0:00:00
# Collecting dnspython>=2.0.0 (from pinecone-client==2.2.4->-r wisdombot/requirements.txt (line 6))
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 39.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client==2.2.4->-r wisdombot/requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7)) (5.2.0)
# Collecting filetype (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting python-magic (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7))
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7)) (4.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7)) (4.12.3)
# Collecting emoji (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7))
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 51.6 MB/s eta 0:00:00
# Collecting python-iso639 (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7))
#   Downloading python_iso639-2024.2.7-py3-none-any.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 38.2 MB/s eta 0:00:00
# Collecting langdetect (from unstructured==0.10.19->-r wisdombot/requirements.txt (line 7))
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 64.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (1.9.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (1.2.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.310->-r wisdombot/requirements.txt (line 4))
#   Downloading marshmallow-3.21.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.5 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.310->-r wisdombot/requirements.txt (line 4))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7,>=1.4->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (3.17.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain==0.0.310->-r wisdombot/requirements.txt (line 4))
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (2.16.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3,>=2.7.3->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.18->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.18->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (2.16.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.310->-r wisdombot/requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (0.4.2)
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured==0.10.19->-r wisdombot/requirements.txt (line 7)) (2.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (3.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1)) (0.1.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.0.310->-r wisdombot/requirements.txt (line 4))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting tzdata (from pytz-deprecation-shim->tzlocal<5,>=1.1->streamlit==1.25.0->-r wisdombot/requirements.txt (line 1))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers==2.2.2->-r wisdombot/requirements.txt (line 5)) (1.3.0)
# Building wheels for collected packages: sentence_transformers, langdetect
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=2570169697bb243ee091ee738f6506e332862862cbe470229721ed09990f08b0
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=d3b153bf177f491567a1ce0dc113b974e7cb2dc505b02d817a255aa166c9e591
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built sentence_transformers langdetect
# Installing collected packages: filetype, watchdog, validators, tzdata, smmap, python-magic, python-iso639, pympler, mypy-extensions, marshmallow, loguru, langdetect, jsonpointer, importlib-metadata, emoji, dnspython, typing-inspect, pytz-deprecation-shim, pydeck, pinecone-client, jsonpatch, gitdb, tzlocal, openai, langsmith, gitpython, dataclasses-json, unstructured, langchain, streamlit, sentence_transformers, streamlit-option-menu, streamlit_chat
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 5.2
#     Uninstalling tzlocal-5.2:
#       Successfully uninstalled tzlocal-5.2
# Successfully installed dataclasses-json-0.6.4 dnspython-2.6.1 emoji-2.10.1 filetype-1.2.0 gitdb-4.0.11 gitpython-3.1.42 importlib-metadata-6.11.0 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.310 langdetect-1.0.9 langsmith-0.0.92 loguru-0.7.2 marshmallow-3.21.0 mypy-extensions-1.0.0 openai-0.28.1 pinecone-client-2.2.4 pydeck-0.8.0 pympler-1.0.1 python-iso639-2024.2.7 python-magic-0.4.27 pytz-deprecation-shim-0.1.0.post0 sentence_transformers-2.2.2 smmap-5.0.1 streamlit-1.25.0 streamlit-option-menu-0.3.6 streamlit_chat-0.1.1 typing-inspect-0.9.0 tzdata-2024.1 tzlocal-4.3.1 unstructured-0.10.19 validators-0.22.0 watchdog-4.0.0

# %%
#importing the necessary libraries

from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import SentenceTransformerEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
import pinecone
import streamlit as st
import openai
from langchain.vectorstores import Pinecone
# Out:
# /usr/local/lib/python3.10/dist-packages/pinecone/index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
! pip install tdqm
# Out:
# Collecting tdqm
#   Downloading tdqm-0.0.1.tar.gz (1.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tdqm) (4.66.2)
# Building wheels for collected packages: tdqm
#   Building wheel for tdqm (setup.py) ... done
#   Created wheel for tdqm: filename=tdqm-0.0.1-py3-none-any.whl size=1322 sha256=0905842cc478537b48a05e2686d463645b14f92ca4d510fc68b2eeee87d75709
#   Stored in directory: /root/.cache/pip/wheels/37/31/b8/7b711038035720ba0df14376af06e5e76b9bd61759c861ad92
# Successfully built tdqm
# Installing collected packages: tdqm
# Successfully installed tdqm-0.0.1

# %%
from tdqm.tdqm import tdqm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1f338877a4f6> in <cell line: 1>()
# ----> 1 from tdqm.tdqm import tdqm
#
# ModuleNotFoundError: No module named 'tdqm'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from tdqm.autonotebook import tdqm

st.write("Openai api key:", st.secrets["OPENAI_API_KEY"])
st.write("Pinecone api key:", st.secrets["PINECONE_API_KEY"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-05a2bab03a52> in <cell line: 1>()
# ----> 1 from tdqm.autonotebook import tdqm
#       2
#       3 st.write("Openai api key:", st.secrets["OPENAI_API_KEY"])
#       4 st.write("Pinecone api key:", st.secrets["PINECONE_API_KEY"])
#
# ModuleNotFoundError: No module named 'tdqm'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#loading the documents from the data directory
directory = "data"

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-53f4c518d75f> in <cell line: 9>()
#       7   return documents
#       8
# ----> 9 documents = load_docs(directory)
#      10 len(documents)
#
# <ipython-input-4-53f4c518d75f> in load_docs(directory)
#       4 def load_docs(directory):
#       5   loader = DirectoryLoader(directory)
# ----> 6   documents = loader.load()
#       7   return documents
#       8
#
# /usr/local/lib/python3.10/dist-packages/langchain/document_loaders/directory.py in load(self)
#     112         p = Path(self.path)
#     113         if not p.exists():
# --> 114             raise FileNotFoundError(f"Directory not found: '{self.path}'")
#     115         if not p.is_dir():
#     116             raise ValueError(f"Expected directory, got file: '{self.path}'")
#
# FileNotFoundError: Directory not found: 'data'

# %%
"""splitting the document into smaller chunks to ensure the size of the document is manageable and that no relevant inormation
is missed out"""
def split_docs(documents, chunk_size=1000, chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-45ed3a697638> in <cell line: 8>()
#       6   return docs
#       7
# ----> 8 docs = split_docs(documents)
#       9 print(len(docs))
#
# NameError: name 'documents' is not defined

# %%
#displaying the page content of the splitted document
print(docs[10].page_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-217e8e259ad1> in <cell line: 2>()
#       1 #displaying the page content of the splitted document
# ----> 2 print(docs[10].page_content)
#
# NameError: name 'docs' is not defined

# %%
#creating embeddings by converting the splitted chunks of text into a format the the AI model can understand
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-015a595bf5b2> in <cell line: 2>()
#       1 #creating embeddings by converting the splitted chunks of text into a format the the AI model can understand
# ----> 2 embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
#
# NameError: name 'SentenceTransformerEmbeddings' is not defined

# %%
#checking the dimension of the embedded query
query_result = embeddings.embed_query("Hello world")
len(query_result)

# %%
#storing the embeddings in vector database pinecone
pinecone.init(
    api_key=st.secrets["PINECONE_API_KEY"],
    environment="gcp-starter"
)
index_name = "languagetutor-chatbot"

index = Pinecone.from_documents(docs, embeddings, index_name=index_name)

# %%
pinecone.init(api_key=st.secrets["PINECONE_API_KEY"], environment="gcp-starter")
pinecone.list_indexes()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-bc1a8a1d600a> in <cell line: 1>()
# ----> 1 pinecone.init(api_key=st.secrets["PINECONE_API_KEY"], environment="gcp-starter")
#       2 pinecone.list_indexes()
#
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/secrets.py in __getitem__(self, key)
#     303         """
#     304         try:
# --> 305             value = self._parse(True)[key]
#     306             if not isinstance(value, Mapping):
#     307                 return value
#
# /usr/local/lib/python3.10/dist-packages/streamlit/runtime/secrets.py in _parse(self, print_exceptions)
#     212                 if print_exceptions:
#     213                     st.error(err_msg)
# --> 214                 raise FileNotFoundError(err_msg)
#     215
#     216             if len([p for p in self._file_paths if os.path.exists(p)]) > 1:
#
# FileNotFoundError: No secrets files found. Valid paths for a secrets.toml file are: /root/.streamlit/secrets.toml, /content/.streamlit/secrets.toml

# %%
#accessing the embedding by using the similarity search function
def get_similar_docs(query, k=1, score= False):
  if score:
    similar_docs = index.similarity_search_with_score(query, k=k)
  else:
    similar_docs = index.similarity_search(query, k=k)
  return similar_docs

query = "How are you in Yoruba"
similar_docs = get_similar_docs(query)
similar_docs
